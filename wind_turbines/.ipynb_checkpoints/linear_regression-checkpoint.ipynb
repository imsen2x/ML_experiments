# %% [markdown]
# ## **This is a Linear Regression Exercise that makes sure all assumptions of a Linear Model are followed.**
#
# <br>
#
# #### 1. Linearity: The predictors and the target variable have a linear relationship.
# #### 2. No Endogeneity: The errors shouldn't be correlated with the target variable
# #### 3. Normality of Residuals and Heteroscedasticity: Residuals should be approximately normally distributed.
# #### Errors hould have low variance.
# #### 4. No to minimal collinearity: Beware of features with high correlation since they mess up the internal calculation of the coefficients.
# #### 5. Autocovariance or No serial correlation: Errors should be randomly positioned around the regression line.
#
# <br>
#
# ### **References**:
# #### I used the Wind Turbine Farm Data from the tidytuesday project.
# #### Here's the link to know about more.
# https://github.com/rfordatascience/tidytuesday/tree/master/data/2018/2018-11-06

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={"figure.figsize":(10, 10)})
pd.set_option("display.max_columns", None)

# %%
wind_turbines_raw = pd.read_csv("wind_turbines.csv")

# %%
wind_turbines_raw.head()
# Out:
#    case_id  faa_ors  faa_asn  usgs_pr_id t_state     t_county  t_fips  \
# 0  3073429  missing  missing  4960        CA      Kern County  6029
# 1  3071522  missing  missing  4997        CA      Kern County  6029
# 2  3073425  missing  missing  4957        CA      Kern County  6029
# 3  3071569  missing  missing  5023        CA      Kern County  6029
# 4  3005252  missing  missing  5768        CA      Kern County  6029
#
#      p_name  p_year  p_tnum  p_cap  t_manu  t_model  t_cap    t_hh    t_rd  \
# 0  251 Wind  1987    194     18.43  Vestas  missing  95    -9999.0 -9999.0
# 1  251 Wind  1987    194     18.43  Vestas  missing  95    -9999.0 -9999.0
# 2  251 Wind  1987    194     18.43  Vestas  missing  95    -9999.0 -9999.0
# 3  251 Wind  1987    194     18.43  Vestas  missing  95    -9999.0 -9999.0
# 4  251 Wind  1987    194     18.43  Vestas  missing  95    -9999.0 -9999.0
#
#     t_rsa  t_ttlh  t_conf_atr  t_conf_loc  t_img_date     t_img_srce  \
# 0 -9999.0 -9999.0  2           3           1/1/2012    NAIP
# 1 -9999.0 -9999.0  2           3           1/1/2012    NAIP
# 2 -9999.0 -9999.0  2           3           1/1/2012    NAIP
# 3 -9999.0 -9999.0  2           3           7/31/2016   Digital Globe
# 4 -9999.0 -9999.0  2           3           11/23/2017  Digital Globe
#
#         xlong       ylat
# 0 -118.360725  35.083778
# 1 -118.361168  35.081512
# 2 -118.360420  35.084709
# 3 -118.364029  35.079418
# 4 -118.354286  35.085594

# %% [markdown]
# #### Replace missing values represented as -9999 to NaN

# %%
wind_processed = wind_turbines_raw.replace(-9999, np.nan)

# %%
# Select there features
wind_selections = wind_processed[["t_cap",
                "t_state",
                "p_year",
                "t_hh",
                "t_rd",
                "t_rsa",
                "t_ttlh",
                "t_conf_atr"]]


wind_selections.shape
# Out:
# (58185, 8)

# %% [markdown]
# #### Remove rows with missing values

# %%
print(wind_selections.dropna(axis = "rows").shape)
# rows were reduced from 58185 to 51548 (~13% less)

wind_selections = wind_selections.dropna(axis = "rows")
# Check if rows still have missing values
# No more missing values
print(wind_selections.isna().mean())
# Out:
# (51548, 8)
# t_cap         0.0
# t_state       0.0
# p_year        0.0
# t_hh          0.0
# t_rd          0.0
# t_rsa         0.0
# t_ttlh        0.0
# t_conf_atr    0.0
# dtype: float64

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ## Linearity

# %%
sns.scatterplot(x = "p_year", y = "t_cap", data = wind_selections)

# %%
sns.scatterplot(x = "t_hh", y = "t_cap", data = wind_selections)

# %%
sns.scatterplot(x = "t_rd", y = "t_cap", data = wind_selections)

# %%
sns.scatterplot(x = "t_rsa", y = "t_cap", data = wind_selections)

# %%
sns.scatterplot(x = "t_ttlh", y = "t_cap", data = wind_selections)

# %%
sns.regplot(x = "t_conf_atr", y = "t_cap", data = wind_selections)

# %% [markdown]
# #### Seems like all selected predictors are somewhat linear with out target variable

# %% [markdown]
# ## Post transformation EDA

# %% [markdown]
# #### Standardize the dataset for a more linear relationship between the predictors and target variable

# %%
from sklearn.preprocessing import StandardScaler

def mass_standardization(df, col_names):
    scaler = StandardScaler()
    for col in col_names:
        df[col] = scaler.fit_transform(df[col].values.reshape(-1,1)).flatten()
    return df

wind_standardized = mass_standardization(wind_selections.copy(), ["p_year", "t_cap", "t_hh", "t_rd", "t_rsa", "t_ttlh", "t_conf_atr"])
wind_standardized.head()
# Out:
#        t_cap t_state    p_year      t_hh      t_rd     t_rsa    t_ttlh  \
# 190  2.13162  IA      1.237445  0.791453  1.872542  2.423964  1.339273
# 191  2.13162  IA      1.237445  0.791453  1.872542  2.423964  1.339273
# 192  2.13162  IA      1.237445  0.791453  1.872542  2.423964  1.339273
# 193  2.13162  IA      1.237445  0.791453  1.872542  2.423964  1.339273
# 194  2.13162  IA      1.237445  0.791453  1.872542  2.423964  1.339273
#
#      t_conf_atr
# 190  0.246778
# 191  0.246778
# 192  0.246778
# 193  0.246778
# 194  0.246778

# %%
wind_standardized.describe()
# Out:
#               t_cap        p_year          t_hh          t_rd         t_rsa  \
# count  5.154800e+04  5.154800e+04  5.154800e+04  5.154800e+04  5.154800e+04
# mean   1.399658e-14  1.498802e-14 -3.336060e-14  1.145545e-15  1.078089e-15
# std    1.000010e+00  1.000010e+00  1.000010e+00  1.000010e+00  1.000010e+00
# min   -2.873378e+00 -4.769285e+00 -4.596994e+00 -3.478310e+00 -2.364234e+00
# 25%   -4.046964e-01 -4.310913e-01  2.082879e-01 -4.206801e-01 -5.798107e-01
# 50%   -6.652088e-02  6.946946e-02  2.082879e-01  5.707457e-02 -7.174764e-02
# 75%    6.098301e-01  7.368838e-01  2.082879e-01  6.781556e-01  6.813635e-01
# max    7.204252e+00  1.404298e+00  4.096056e+00  3.066929e+00  4.553806e+00
#
#              t_ttlh    t_conf_atr
# count  5.154800e+04  5.154800e+04
# mean   7.045639e-15  1.598680e-15
# std    1.000010e+00  1.000010e+00
# min   -4.213417e+00 -8.316625e+00
# 25%   -7.479433e-02  2.467785e-01
# 50%    1.413688e-01  2.467785e-01
# 75%    4.611100e-01  2.467785e-01
# max    3.505407e+00  2.467785e-01

# %% [markdown]
# #### Re-check linearity

# %%
sns.regplot(x = "p_year", y = "t_cap", data = wind_standardized)

# %%
sns.regplot(x = "t_hh", y = "t_cap", data = wind_standardized)

# %%
sns.regplot(x = "t_rd", y = "t_cap", data = wind_standardized)

# %%
sns.regplot(x = "t_rsa", y = "t_cap", data = wind_standardized)

# %%
sns.regplot(x = "t_ttlh", y = "t_cap", data = wind_standardized)

# %%
sns.regplot(x = "t_conf_atr", y = "t_cap", data = wind_standardized)

# %% [markdown]
# ## Collinearity

# %% [markdown]
# #### Make a correlation heat map of the selected features

# %%
corr = wind_standardized.corr()
sns.heatmap(corr, annot=True)

# %% [markdown]
# #### It seems that most features are highly correlated with each other. This could possibly be bad but let's proceed with these factors for now since I assume that all of them seems to be good predictors of t_cap.

# %% [markdown]
# ## Experiment
# #### - Check if a feature with higher correlation with the target variable predicts better than a feature with a lower one.
# ### Conclusion
# #### - It seems that features with higher correlation with our target variable predicts better than the lower one.

# %%
exp_corr = wind_standardized[["t_cap", "t_hh", "t_rsa"]].corr()
exp_corr
# Out:
#           t_cap      t_hh     t_rsa
# t_cap  1.000000  0.712919  0.845721
# t_hh   0.712919  1.000000  0.711468
# t_rsa  0.845721  0.711468  1.000000

# %%
import statsmodels.api as sm

y = wind_standardized["t_cap"]
x1 = sm.add_constant(wind_standardized["t_hh"])
x2 = sm.add_constant(wind_standardized["t_rsa"])

sm.OLS(y, x1).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  t_cap   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                 5.328e+04
# Date:                Sat, 22 Aug 2020   Prob (F-statistic):               0.00
# Time:                        17:41:33   Log-Likelihood:                -54849.
# No. Observations:               51548   AIC:                         1.097e+05
# Df Residuals:                   51546   BIC:                         1.097e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.563e-16      0.003   2.45e-13      1.000      -0.006       0.006
# t_hh           0.7129      0.003    230.816      0.000       0.707       0.719
# ==============================================================================
# Omnibus:                     5170.322   Durbin-Watson:                   0.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7169.696
# Skew:                           0.808   Prob(JB):                         0.00
# Kurtosis:                       3.853   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sm.OLS(y, x2).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  t_cap   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.715
# Method:                 Least Squares   F-statistic:                 1.295e+05
# Date:                Sat, 22 Aug 2020   Prob (F-statistic):               0.00
# Time:                        17:41:53   Log-Likelihood:                -40768.
# No. Observations:               51548   AIC:                         8.154e+04
# Df Residuals:                   51546   BIC:                         8.156e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.563e-16      0.002   3.22e-13      1.000      -0.005       0.005
# t_rsa          0.8457      0.002    359.823      0.000       0.841       0.850
# ==============================================================================
# Omnibus:                     7544.388   Durbin-Watson:                   0.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16604.868
# Skew:                           0.872   Prob(JB):                         0.00
# Kurtosis:                       5.165   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ##
# 55167  0           0           0           0           0           0
# 55168  0           0           0           0           0           0
# 55368  0           0           0           1           0           0
# 55531  0           0           0           0           0           0
# 55532  0           0           0           0           0           0
#
#        t_state_OR  t_state_PA  t_state_PR  t_state_RI  t_state_SD  t_state_TN  \
# 190    0           0           0           0           0           0
# 191    0           0           0           0           0           0
# 192    0           0           0           0           0           0
# 193    0           0           0           0           0           0
# 194    0           0           0           0           0           0
# ...   ..          ..          ..          ..          ..          ..
# 55167  0           0           0           0           0           0
# 55168  0           0           0           0           0           0
# 55368  0           0           0           0           0           0
# 55531  0           0           0           0           0           0
# 55532  0           0           0           0           0           0
#
#        t_state_TX  t_state_UT  t_state_VT  t_state_WA  t_state_WI  t_state_WV  \
# 190    0           0           0           0           0           0
# 191    0           0           0           0           0           0
# 192    0           0           0           0           0           0
# 193    0           0           0           0           0           0
# 194    0           0           0           0           0           0
# ...   ..          ..          ..          ..          ..          ..
# 55167  1           0           0           0           0           0
# 55168  1           0           0           0           0           0
# 55368  0           0           0           0           0           0
# 55531  0           0           0           0           0           0
# 55532  0           0           0           0           0           0
#
#        t_state_WY
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# ...   ..
# 55167  0
# 55168  0
# 55368  0
# 55531  0
# 55532  0
#
# [51548 rows x 50 columns]

# %%
xs = sm.add_constant(wind_dummified.iloc[:, 1:])
final_model = sm.OLS(y, xs).fit()

# %%
final_model.summary()
# I'm not happy with the model even if we had a high R-squared values, since some coefficients doesn't make sense.
# Most coefficients numeric should be positive. Based on our EDAs as t_cap increases these coefficients also increase.
# This might be the effect of multicollinearity.
# We'll again model but this time with different sets of predictors.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  t_cap   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     4891.
# Date:                Sat, 22 Aug 2020   Prob (F-statistic):               0.00
# Time:                        22:51:59   Log-Likelihood:                -28931.
# No. Observations:               51548   AIC:                         5.796e+04
# Df Residuals:                   51499   BIC:                         5.839e+04
# Df Model:                          48
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1552      0.016      9.414      0.000       0.123       0.188
# p_year        -0.3201      0.005    -69.345      0.000      -0.329      -0.311
# t_hh           5.1635      0.238     21.661      0.000       4.696       5.631
# t_rd           5.6565      0.196     28.921      0.000       5.273       6.040
# t_rsa         -0.3970      0.012    -32.015      0.000      -0.421      -0.373
# t_ttlh        -8.7607      0.412    -21.273      0.000      -9.568      -7.954
# t_conf_atr     0.0637      0.002     32.193      0.000       0.060       0.068
# t_state_AK     0.8498      0.043     19.770      0.000       0.766       0.934
# t_state_AZ    -0.0231      0.038     -0.603      0.547      -0.098       0.052
# t_state_CA     0.2662      0.018     14.648      0.000       0.231       0.302
# t_state_CO    -0.4023      0.019    -21.235      0.000      -0.439      -0.365
# t_state_CT     1.0117      0.294      3.445      0.001       0.436       1.587
# t_state_DE     0.0429      0.415      0.103      0.918      -0.770       0.856
# t_state_GU     0.9296      0.415      2.239      0.025       0.116       1.744
# t_state_HI     0.2596      0.042      6.251      0.000       0.178       0.341
# t_state_IA    -0.1819      0.018    -10.261      0.000      -0.217      -0.147
# t_state_ID    -0.2891      0.024    -11.889      0.000      -0.337      -0.241
# t_state_IL    -0.2633      0.018    -14.260      0.000      -0.300      -0.227
# t_state_IN    -0.3309      0.020    -16.214      0.000      -0.371      -0.291
# t_state_KS    -0.3112      0.018    -17.017      0.000      -0.347      -0.275
# t_state_MA     0.1089      0.048      2.256      0.024       0.014       0.203
# t_state_MD     0.5882      0.050     11.745      0.000       0.490       0.686
# t_state_ME     0.5485      0.027     20.423      0.000       0.496       0.601
# t_state_MI    -0.6472      0.021    -30.731      0.000      -0.688      -0.606
# t_state_MN    -0.1684      0.018     -9.110      0.000      -0.205      -0.132
# t_state_MO    -0.4134      0.025    -16.648      0.000      -0.462      -0.365
# t_state_MT    -0.1788      0.025     -7.099      0.000      -0.228      -0.129
# t_state_NC    -0.8764      0.044    -19.871      0.000      -0.963      -0.790
# t_state_ND    -0.1241      0.019     -6.380      0.000      -0.162      -0.086
# t_state_NE    -0.4751      0.022    -21.393      0.000      -0.519      -0.432
# t_state_NH     0.9869      0.051     19.486      0.000       0.888       1.086
# t_state_NJ    -0.3221      0.170     -1.894      0.058      -0.655       0.011
# t_state_NM    -0.2502      0.021    -11.870      0.000      -0.291      -0.209
# t_state_NV     0.0593      0.054      1.104      0.270      -0.046       0.165
# t_state_NY    -0.1864      0.021     -8.901      0.000      -0.227      -0.145
# t_state_OH    -0.2704      0.029     -9.477      0.000      -0.326      -0.214
# t_state_OK    -0.1671      0.018     -9.340      0.000      -0.202      -0.132
# t_state_OR     0.0114      0.019      0.595      0.552      -0.026       0.049
# t_state_PA     0.0370      0.023      1.638      0.101      -0.007       0.081
# t_state_PR    -0.2831      0.056     -5.048      0.000      -0.393      -0.173
# t_state_RI     0.9207      0.085     10.870      0.000       0.755       1.087
# t_state_SD    -0.1778      0.024     -7.455      0.000      -0.225      -0.131
# t_state_TN    -0.1461      0.099     -1.473      0.141      -0.340       0.048
# t_state_TX    -0.1949      0.017    -11.533      0.000      -0.228      -0.162
# t_state_UT    -0.0707      0.033     -2.120      0.034      -0.136      -0.005
# t_state_VT     0.5754      0.052     11.146      0.000       0.474       0.677
# t_state_WA     0.0064      0.019      0.327      0.744      -0.032       0.044
# t_state_WI    -0.2923      0.025    -11.520      0.000      -0.342      -0.243
# t_state_WV     0.1084      0.027      4.010      0.000       0.055       0.161
# t_state_WY    -0.1095      0.021     -5.186      0.000      -0.151      -0.068
# ==============================================================================
# Omnibus:                    10611.486   Durbin-Watson:                   0.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36135.999
# Skew:                           1.029   Prob(JB):                         0.00
# Kurtosis:                       6.548   Cond. No.                     4.28e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.28e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
set1 = ["t_cap", "t_state", "p_year", "t_rsa", "t_ttlh"] 
set2 = ["t_cap", "t_state", "t_hh", "t_rd"]
set3 = ["t_cap", "t_state", "p_year", "t_ttlh", "t_rsa"]
set3 = ["t_cap", "t_state", "t_ttlh", "t_rsa"]

# %%
y_set1 = wind_standardized["t_cap"]
# Transform the categorical variables into Dummy Encoded columns
wind_dummified_set1 = pd.get_dummies(wind_standardized[set1])
wind_dummified_set1


xs_set1 = sm.add_constant(wind_dummified_set1.iloc[:, 1:])
set1_model = sm.OLS(y_set1, xs_set1).fit()
set1_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                
# t_state_RI     0.5572      0.091      6.157      0.000       0.380       0.735
# t_state_SD    -0.0777      0.025     -3.046      0.002      -0.128      -0.028
# t_state_TN    -0.0429      0.106     -0.404      0.686      -0.251       0.165
# t_state_TX    -0.1470      0.018     -8.135      0.000      -0.182      -0.112
# t_state_UT     0.0144      0.036      0.405      0.686      -0.055       0.084
# t_state_VT     0.5929      0.055     10.738      0.000       0.485       0.701
# t_state_WA     0.2139      0.021     10.359      0.000       0.173       0.254
# t_state_WI    -0.2576      0.027     -9.488      0.000      -0.311      -0.204
# t_state_WV     0.2306      0.029      7.981      0.000       0.174       0.287
# t_state_WY    -0.0342      0.023     -1.517      0.129      -0.078       0.010
# ==============================================================================
# Omnibus:                     8182.983   Durbin-Watson:                   0.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22221.454
# Skew:                           0.867   Prob(JB):                         0.00
# Kurtosis:                       5.709   Cond. No.                     3.17e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.41e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
y_set2 = wind_standardized["t_cap"]
# Transform the categorical variables into Dummy Encoded columns
wind_dummified_set2 = pd.get_dummies(wind_standardized[set2])
wind_dummified_set2

xs_set2 = sm.add_constant(wind_dummified_set2.iloc[:, 1:])
set2_model = sm.OLS(y_set2, xs_set2).fit()
set2_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  t_cap   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.799
# Method:                 Least Squares   F-statistic:                     4653.
# Date:                Sat, 22 Aug 2020   Prob (F-statistic):               0.00
# Time:                        23:23:10   Log-Likelihood:                -31792.
# No. Observations:               51548   AIC:                         6.367e+04
# Df Residuals:                   51503   BIC:                         6.407e+04
# Df Model:                          44
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1023      0.017      5.878      0.000       0.068       0.136
# t_hh           0.1044      0.004     26.728      0.000       0.097       0.112
# t_rd           0.8533      0.004    234.371      0.000       0.846       0.860
# t_state_AK     0.1307      0.044      2.978      0.003       0.045       0.217
# t_state_AZ     0.0090      0.040      0.222      0.825      -0.070       0.088
# t_state_CA     0.3050      0.019     15.940      0.000       0.267       0.342
# t_state_CO    -0.3348      0.020    -16.746      0.000      -0.374      -0.296
# t_state_CT     0.9580      0.310      3.087      0.002       0.350       1.566
# t_state_DE     0.1619      0.439      0.369      0.712      -0.698       1.022
# t_state_GU    -0.2037      0.439     -0.464      0.642      -1.063       0.656
# t_state_HI     0.2470      0.044      5.638      0.000       0.161       0.333
# t_state_IA    -0.0802      0.019     -4.294      0.000      -0.117      -0.044
# t_state_ID    -0.1889      0.026     -7.363      0.000      -0.239      -0.139
# t_state_IL    -0.2500      0.019    -12.824      0.000      -0.288      -0.212
# t_state_IN    -0.2703      0.022    -12.542      0.000      -0.313      -0.228
# t_state_KS    -0.2836      0.019    -14.684      0.000      -0.321      -0.246
# t_state_MA    -0.0905      0.051     -1.778      0.075      -0.190       0.009
# t_state_MD     0.6771      0.053     12.797      0.000       0.573       0.781
# t_state_ME     0.5858      0.028     20.649      0.000       0.530       0.641
# t_state_MI    -0.5982      0.022    -26.982      0.000      -0.642      -0.555
# t_state_MN    -0.1071      0.020     -5.490      0.000      -0.145      -0.069
# t_state_MO    -0.3838      0.026    -14.641      0.000      -0.435      -0.332
# t_state_MT    -0.1922      0.027     -7.229      0.000      -0.244      -0.140
# t_state_NC    -0.9382      0.046    -20.191      0.000      -1.029      -0.847
# t_state_ND    -0.0936      0.021     -4.556      0.000      -0.134      -0.053
# t_state_NE    -0.4650      0.023    -19.826      0.000      -0.511      -0.419
# t_state_NH     1.0133      0.054     18.935      0.000       0.908       1.118
# t_state_NJ    -0.1495      0.180     -0.832      0.406      -0.502       0.203
# t_state_NM    -0.2075      0.022     -9.324      0.000      -0.251      -0.164
# t_state_NV     0.2045      0.057      3.605      0.000       0.093       0.316
# t_state_NY    -0.0734      0.022     -3.325      0.001      -0.117      -0.030
# t_state_OH    -0.3162      0.030    -10.532      0.000      -0.375      -0.257
# t_state_OK    -0.1326      0.019     -7.015      0.000      -0.170      -0.096
# t_state_OR     0.1251      0.020      6.211      0.000       0.086       0.165
# t_state_PA     0.1286      0.024      5.399      0.000       0.082       0.175
# t_state_PR    -0.1995      0.059     -3.367      0.001      -0.316      -0.083
# t_state_RI     0.6072      0.089      6.795      0.000       0.432       0.782
# t_state_SD    -0.1208      0.025     -4.797      0.000      -0.170      -0.071
# t_state_TN     0.1384      0.105      1.321      0.186      -0.067       0.344
# t_state_TX    -0.1511      0.018     -8.472      0.000      -0.186      -0.116
# t_state_UT     0.0044      0.035      0.126      0.900      -0.065       0.073
# t_state_VT     0.5268      0.055      9.659      0.000       0.420       0.634
# t_state_WA     0.1620      0.020      7.937      0.000       0.122       0.202
# t_state_WI    -0.2073      0.027     -7.739      0.000      -0.260      -0.155
# t_state_WV     0.1917      0.029      6.720      0.000       0.136       0.248
# t_state_WY    -0.0362      0.022     -1.625      0.104      -0.080       0.007
# ==============================================================================
# Omnibus:                    10888.699   Durbin-Watson:                   0.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33172.404
# Skew:                           1.093   Prob(JB):                         0.00
# Kurtosis:                       6.266   Cond. No.                     3.43e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.02e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
y_set3 = wind_standardized["t_cap"]
# Transform the categorical variables into Dummy Encoded columns
wind_dummified_set3 = pd.get_dummies(wind_standardized[set3])
wind_dummified_set3

xs_set3 = sm.add_constant(wind_dummified_set3.iloc[:, 1:])
set3_model = sm.OLS(y_set3, xs_set3).fit()
set3_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  t_cap   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     4411.
# Date:                Sat, 22 Aug 2020   Prob (F-statistic):               0.00
# Time:                        23:23:52   Log-Likelihood:                -32427.
# No. Observations:               51548   AIC:                         6.495e+04
# Df Residuals:                   51502   BIC:                         6.535e+04
# Df Model:                          45
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22221.454
# Skew:                           0.867   Prob(JB):                         0.00
# Kurtosis:                       5.709   Cond. No.                     3.28e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.31e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
final_model.fittedvalues
# Out:
# 190      1.576308
# 191      1.576308
# 192      1.576308
# 193      1.576308
# 194      1.576308
#            ...
# 55167    0.445913
# 55168    0.445913
# 55368   -4.448379
# 55531   -3.720042
# 55532   -3.720042
# Length: 51548, dtype: float64

# %%
np.sqrt(np.mean(final_model.resid.values**2))
# Out:
# 0.42414278843205716

# %%
np.std(wind_standardized["t_cap"].values)
# Out:
# 1.0

# %% [markdown]
# # No Endogeneity

# %%
## This is a Linear Regression Exercise that makes sure all assumptions of a Linear Model are followed
### 1. Linearity: The predictors and the target variable have a linear relationship.
### 2. No Endogeneity: The errors shouldn't be correlated with the target variable
### 3. Normality of Residuals and Heteroscedasticity: Residuals should be approximately normally distributed
### 4. No to minimal collinearity: Beware of features with high correlation
### 5. Autocovariance or No serial correlation: Errors should be randomly positioned around the regression line

print("Correlation Between the errors and the target variable:\n", np.corrcoef(wind_standardized["t_cap"], final_model.resid.values))
# Out:
# Correlation Between the errors and the target variable:
#  [[1.         0.42414279]
#  [0.42414279 1.        ]]

# %% [markdown]
# ### The correlation seems acceptable let's double check using a graph.

# %%
sns.regplot(wind_standardized["t_cap"], final_model.resid.values)

# %% [markdown]
# ### Based on the graph the errors are quite random and it seems that the correlation is acceptable

# %% [markdown]
# # Normality of Residuals and Heteroscedasticity

# %%
print("Heteroscedasticity:")
print("Target variable variance vs residual variance:")
print(np.var(wind_standardized["t_cap"]), np.var(final_model.resid.values))
# Out:
# Heteroscedasticity:
# Target variable variance vs residual variance:
# 1.0000000000000826 0.17989710497892084

# %%
sns.distplot(final_model.resid.values)

# %%
y2 = wind_standardized["t_cap"]
wind_dummified2 = wind_standardized.drop("p_year", axis = "columns")
wind_dummified2 = pd.get_dummies(wind_dummified2)
xs2 = sm.add_constant(wind_dummified2.iloc[:, 1:])
final_model2 = sm.OLS(y2, xs2).fit()

# %%
# wind_dummified2
final_model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  t_cap   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     4475.
# Date:                Sat, 22 Aug 2020   Prob (F-statistic):               0.00
# Time:                        18:48:28   Log-Likelihood:                -31232.
# No. Observations:               51548   AIC:                         6.256e+04
# Df Residuals:                   51500   BIC:                         6.299e+04
# Df Model:                          47
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1066      0.017      6.187      0.000       0.073       0.140
# t_hh           5.0993      0.249     20.459      0.000       4.611       5.588
# t_rd           5.2508      0.204     25.686      0.000       4.850       5.652
# t_rsa         -0.2425      0.013    -19.011      0.000      -0.268      -0.218
# t_ttlh        -8.7300      0.431    -20.273      0.000      -9.574      -7.886
# t_conf_atr     0.0406      0.002     19.903      0.000       0.037       0.045
# t_state_AK     0.1909      0.044      4.354      0.000       0.105       0.277
# t_state_AZ    -0.0107      0.040     -0.267      0.789      -0.089       0.068
# t_state_CA     0.3372      0.019     17.774      0.000       0.300       0.374
# t_state_CO    -0.3612      0.020    -18.246      0.000      -0.400      -0.322
# t_state_CT     1.0155      0.307      3.308      0.001       0.414       1.617
# t_state_DE     0.1415      0.434      0.326      0.744      -0.709       0.992
# t_state_GU    -0.1204      0.434     -0.277      0.781      -0.971       0.730
# t_state_HI     0.2017      0.043      4.647      0.000       0.117       0.287
# t_state_IA    -0.0907      0.018     -4.907      0.000      -0.127      -0.054
# t_state_ID    -0.2086      0.025     -8.212      0.000      -0.258      -0.159
# t_state_IL    -0.2321      0.019    -12.025      0.000      -0.270      -0.194
# t_state_IN    -0.2694      0.021    -12.636      0.000      -0.311      -0.228
# t_state_KS    -0.2965      0.019    -15.508      0.000      -0.334      -0.259
# t_state_MA    -0.1003      0.050     -1.990      0.047      -0.199      -0.002
# t_state_MD     0.6656      0.052     12.714      0.000       0.563       0.768
# t_state_ME     0.5929      0.028     21.119      0.000       0.538       0.648
# t_state_MI    -0.5754      0.022    -26.164      0.000      -0.619      -0.532
# t_state_MN    -0.1188      0.019     -6.151      0.000      -0.157      -0.081
# t_state_MO    -0.3598      0.026    -13.864      0.000      -0.411      -0.309
# t_state_MT    -0.1929      0.026     -7.322      0.000      -0.244      -0.141
# t_state_NC    -0.8832      0.046    -19.152      0.000      -0.974      -0.793
# t_state_ND    -0.0956      0.020     -4.702      0.000      -0.135      -0.056
# t_state_NE    -0.4833      0.023    -20.816      0.000      -0.529      -0.438
# t_state_NH     0.9871      0.053     18.639      0.000       0.883       1.091
# t_state_NJ    -0.1596      0.178     -0.898      0.369      -0.508       0.189
# t_state_NM    -0.2383      0.022    -10.812      0.000      -0.281      -0.195
# t_state_NV     0.1634      0.056      2.911      0.004       0.053       0.273
# t_state_NY    -0.0777      0.022     -3.558      0.000      -0.120      -0.035
# t_state_OH    -0.2483      0.030     -8.323      0.000      -0.307      -0.190
# t_state_OK    -0.1410      0.019     -7.537      0.000      -0.178      -0.104
# t_state_OR     0.0959      0.020      4.804      0.000       0.057       0.135
# t_state_PA     0.1296      0.024      5.498      0.000       0.083       0.176
# t_state_PR    -0.1862      0.059     -3.176      0.001      -0.301      -0.071
# t_state_RI     0.6801      0.088      7.686      0.000       0.507       0.854
# t_state_SD    -0.1531      0.025     -6.140      0.000      -0.202      -0.104
# t_state_TN     0.1319      0.104      1.272      0.203      -0.071       0.335
# t_state_TX    -0.1527      0.018     -8.649      0.000      -0.187      -0.118
# t_state_UT    -0.0078      0.035     -0.223      0.823      -0.076       0.061
# t_state_VT     0.5334      0.054      9.882      0.000       0.428       0.639
# t_state_WA     0.1168      0.020      5.762      0.000       0.077       0.157
# t_state_WI    -0.2164      0.027     -8.163      0.000      -0.268      -0.164
# t_state_WV     0.1529      0.028      5.409      0.000       0.097       0.208
# t_state_WY    -0.0496      0.022     -2.247      0.025      -0.093      -0.006
# ==============================================================================
# Omnibus:                    11006.816   Durbin-Watson:                   0.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35659.556
# Skew:                           1.083   Prob(JB):                         0.00
# Kurtosis:                       6.451   Cond. No.                     3.26e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.81e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
